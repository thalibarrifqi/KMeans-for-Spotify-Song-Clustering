# %% [markdown]
# # **Spotify Song Clustering**

# %% [markdown]
# <img src="playlist.JPG">

# %% [markdown]
# In this project, I will try to cluster songs from Spotify playlists based on their song feature data. I use a playlist that Spotify created and in that playlist doesn't have a specific genre, I used the "Best of the decade for you" playlist. The KMeans clustering will be used as the machine learning algorithm, beacuse it is simple and easy to understand.

# %% [markdown]
# # **Tools**

# %% [markdown]
# 1. Jupyter Notebook
# 2. Spotify App in Spotify Developer
# 3. Spotipy Library
# 4. Pandas, Seaborn, Matplotlib
# 5. Scikit-learn

# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from sklearn.cluster import KMeans

# %% [markdown]
# # **Connect to spotify API**

# %%
client_id = '1ddd57098bc5457aad92a39c29a1700b'
client_secret = 'ffff8ed1d8b7467dbc8071be5381620b'
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# # **Get the Song**

# %% [markdown]
# **Get Track IDs**

# %%
def show_tracks(results, uriArray):
    for i, item in enumerate(results['items']):
        track = item['track']
        uriArray.append(track['id'])

# %%
def track_id(username, playlist_id):
    trackID = []
    results = sp.user_playlist(username, playlist_id)
    tracks = results['tracks']
    show_tracks(tracks, trackID)
    while tracks['next']:
        tracks = sp.next(tracks)
        show_tracks(tracks, trackID)
    return trackID

# %%
#Add the playlist creator and playlist uri
ids = track_id('Spotify', '37i9dQZF1DWXADZ9KRTmmm')

# %%
# 1st uri 37i9dQZF1DXaMu9xyX1HzK
# 2nd uri 37i9dQZF1DWXADZ9KRTmmm

# %% [markdown]
# **Get Track Features data**

# %%
def getTrackFeatures(id):
    meta = sp.track(id)
    features = sp.audio_features(id)

    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    release_date = meta['album']['release_date']
    length = meta['duration_ms']
    popularity = meta['popularity']

    acousticness = features[0]['acousticness']
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    instrumentalness = features[0]['instrumentalness']
    liveness = features[0]['liveness']
    loudness = features[0]['loudness']
    speechiness = features[0]['speechiness']
    tempo = features[0]['tempo']
    time_signature = features[0]['time_signature']

    track = [name, album, artist, release_date, length, popularity, 
             acousticness, danceability, energy, instrumentalness, liveness, loudness, 
             speechiness, tempo, time_signature]
    return track

# %%
tracks = []
for i in range(len(ids)):
    track = getTrackFeatures(ids[i])
    tracks.append(track)

# %% [markdown]
# **Save to csv**

# %%
dff = pd.DataFrame(tracks, columns = [
    'name', 'album', 'artist', 'release_date', 'length', 'popularity', 
    'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 
    'speechiness', 'tempo', 'time_signature'])
dff.to_csv("song_of_decade_2.csv", sep = ',', index=False)

# %% [markdown]
# **Import the playlist**

# %% [markdown]
# For the record I use two playlist for this project, 1st uri and 2nd uri.

# %%
df1 = pd.read_csv('song_of_decade_1.csv')

# %%
df1.head()
# Out:
#                       name                                    album  \
# 0              Blank Space                                     1989
# 1         Story of My Life               Midnight Memories (Deluxe)
# 2         I Like Me Better  I met you when I was 18. (the playlist)
# 3  Scars To Your Beautiful                     Know-It-All (Deluxe)
# 4         Treat You Better                               Illuminate
#
#           artist release_date  length  popularity  acousticness  danceability  \
# 0   Taylor Swift   2014-01-01  231826          67        0.0850         0.752
# 1  One Direction   2013-11-25  245493          82        0.2250         0.600
# 2           Lauv   2018-05-31  197436          83        0.5350         0.752
# 3   Alessia Cara   2015-11-13  230226          73        0.0285         0.573
# 4   Shawn Mendes   2017-04-20  187973          83        0.1060         0.444
#
#    energy  instrumentalness  liveness  loudness  speechiness    tempo  \
# 0   0.678          0.000002     0.130    -5.421       0.0646   96.009
# 1   0.663          0.000000     0.119    -5.802       0.0477  121.070
# 2   0.505          0.000003     0.104    -7.621       0.2530   91.970
# 3   0.739          0.000000     0.111    -5.740       0.1290   97.085
# 4   0.819          0.000000     0.107    -4.078       0.3410   82.695
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
df2 = pd.read_csv('song_of_decade_2.csv')

# %%
df2.head()
# Out:
#                                                 name  \
# 0                    There's Nothing Holdin' Me Back
# 1  Rewrite The Stars (with James Arthur & Anne-Ma...
# 2                                               Maps
# 3                                             Arcade
# 4                                   Story of My Life
#
#                               album           artist release_date  length  \
# 0               Illuminate (Deluxe)     Shawn Mendes   2017-04-20  199440
# 1  The Greatest Showman: Reimagined  Various Artists   2018-11-16  218293
# 2                        V (Deluxe)         Maroon 5   2015-05-18  189960
# 3                            Arcade  Duncan Laurence   2019-03-07  183624
# 4        Midnight Memories (Deluxe)    One Direction   2013-11-25  245493
#
#    popularity  acousticness  danceability  energy  instrumentalness  liveness  \
# 0          83        0.3800         0.866   0.813           0.00000    0.0779
# 1          64        0.2370         0.670   0.743           0.00000    0.4650
# 2          60        0.0205         0.742   0.713           0.00000    0.0590
# 3          83        0.8180         0.450   0.329           0.00109    0.1350
# 4          82        0.2250         0.600   0.663           0.00000    0.1190
#
#    loudness  speechiness    tempo  time_signature
# 0    -4.063       0.0554  121.998               4
# 1    -4.993       0.0393  125.944               4
# 2    -5.522       0.0303  120.032               4
# 3   -12.603       0.0441   71.884               3
# 4    -5.802       0.0477  121.070               4

# %%
df = pd.concat([df1,df2], axis=0)

# %%
df.head()
# Out:
#                       name                                    album  \
# 0              Blank Space                                     1989
# 1         Story of My Life               Midnight Memories (Deluxe)
# 2         I Like Me Better  I met you when I was 18. (the playlist)
# 3  Scars To Your Beautiful                     Know-It-All (Deluxe)
# 4         Treat You Better                               Illuminate
#
#           artist release_date  length  popularity  acousticness  danceability  \
# 0   Taylor Swift   2014-01-01  231826          67        0.0850         0.752
# 1  One Direction   2013-11-25  245493          82        0.2250         0.600
# 2           Lauv   2018-05-31  197436          83        0.5350         0.752
# 3   Alessia Cara   2015-11-13  230226          73        0.0285         0.573
# 4   Shawn Mendes   2017-04-20  187973          83        0.1060         0.444
#
#    energy  instrumentalness  liveness  loudness  speechiness    tempo  \
# 0   0.678          0.000002     0.130    -5.421       0.0646   96.009
# 1   0.663          0.000000     0.119    -5.802       0.0477  121.070
# 2   0.505          0.000003     0.104    -7.621       0.2530   91.970
# 3   0.739          0.000000     0.111    -5.740       0.1290   97.085
# 4   0.819          0.000000     0.107    -4.078       0.3410   82.695
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# **Check redudancy data**

# %%
duplicate = pd.concat(g for _, g in df.groupby('name') if len(g) > 1)

# %%
duplicate.head()
# Out:
#                             name                                  album  \
# 70                       7 rings                          thank u, next
# 113                      7 rings                                7 rings
# 79                     All of Me  Love In The Future (Expanded Edition)
# 41                     All of Me  Love In The Future (Expanded Edition)
# 91   Always Remember Us This Way              A Star Is Born Soundtrack
#
#             artist release_date  length  popularity  acousticness  \
# 70   Ariana Grande   2019-02-08  178626          85         0.592
# 113  Ariana Grande   2019-01-18  178640           2         0.578
# 79     John Legend   2013-08-30  269560          86         0.922
# 41     John Legend   2013-08-30  269560          86         0.922
# 91       Lady Gaga   2018-10-05  210200          72         0.299
#
#      danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 70          0.778   0.317               0.0    0.0881   -10.732       0.3340
# 113         0.725   0.321               0.0    0.0884   -10.744       0.3230
# 79          0.422   0.264               0.0    0.1320    -7.064       0.0322
# 41          0.422   0.264               0.0    0.1320    -7.064       0.0322
# 91          0.553   0.502               0.0    0.7640    -5.972       0.0409
#
#        tempo  time_signature
# 70   140.048               4
# 113   70.142               4
# 79   119.930               4
# 41   119.930               4
# 91   129.976               4

# %%
df = df.sort_values('name')

# %%
df.head()
# Out:
#                          name                      album         artist  \
# 5                        2002   Speak Your Mind (Deluxe)     Anne-Marie
# 118  2U (feat. Justin Bieber)                          7   David Guetta
# 87                    7 Years  Lukas Graham (Blue Album)   Lukas Graham
# 113                   7 rings                    7 rings  Ariana Grande
# 103       A Sky Full of Stars              Ghost Stories       Coldplay
#
#     release_date  length  popularity  acousticness  danceability  energy  \
# 5     2018-04-27  186986          82       0.03720         0.697   0.683
# 118   2018-09-14  194893          61       0.23400         0.534   0.613
# 87    2015-06-16  237300          52       0.29000         0.742   0.479
# 113   2019-01-18  178640           2       0.57800         0.725   0.321
# 103   2014-05-19  267866          78       0.00617         0.545   0.675
#
#      instrumentalness  liveness  loudness  speechiness    tempo  \
# 5             0.00000    0.1370    -2.881       0.1170   96.133
# 118           0.00000    0.2270    -7.410       0.0591  144.878
# 87            0.00000    0.3910    -5.830       0.0551  119.951
# 113           0.00000    0.0884   -10.744       0.3230   70.142
# 103           0.00197    0.2090    -6.474       0.0279  124.970
#
#      time_signature
# 5                 4
# 118               4
# 87                4
# 113               4
# 103               4

# %%
df = df.drop_duplicates(subset='name')

# %%
df.head()
# Out:
#                          name                      album         artist  \
# 5                        2002   Speak Your Mind (Deluxe)     Anne-Marie
# 118  2U (feat. Justin Bieber)                          7   David Guetta
# 87                    7 Years  Lukas Graham (Blue Album)   Lukas Graham
# 113                   7 rings                    7 rings  Ariana Grande
# 103       A Sky Full of Stars              Ghost Stories       Coldplay
#
#     release_date  length  popularity  acousticness  danceability  energy  \
# 5     2018-04-27  186986          82       0.03720         0.697   0.683
# 118   2018-09-14  194893          61       0.23400         0.534   0.613
# 87    2015-06-16  237300          52       0.29000         0.742   0.479
# 113   2019-01-18  178640           2       0.57800         0.725   0.321
# 103   2014-05-19  267866          78       0.00617         0.545   0.675
#
#      instrumentalness  liveness  loudness  speechiness    tempo  \
# 5             0.00000    0.1370    -2.881       0.1170   96.133
# 118           0.00000    0.2270    -7.410       0.0591  144.878
# 87            0.00000    0.3910    -5.830       0.0551  119.951
# 113           0.00000    0.0884   -10.744       0.3230   70.142
# 103           0.00197    0.2090    -6.474       0.0279  124.970
#
#      time_signature
# 5                 4
# 118               4
# 87                4
# 113               4
# 103               4

# %% [markdown]
# **Clustering**

# %%
dataset = df.drop(['name', 'album', 'artist', 'release_date'], axis=1)

# %%
dataset.head()
# Out:
#      length  popularity  acousticness  danceability  energy  instrumentalness  \
# 5    186986          82       0.03720         0.697   0.683           0.00000
# 118  194893          61       0.23400         0.534   0.613           0.00000
# 87   237300          52       0.29000         0.742   0.479           0.00000
# 113  178640           2       0.57800         0.725   0.321           0.00000
# 103  267866          78       0.00617         0.545   0.675           0.00197
#
#      liveness  loudness  speechiness    tempo  time_signature
# 5      0.1370    -2.881       0.1170   96.133               4
# 118    0.2270    -7.410       0.0591  144.878               4
# 87     0.3910    -5.830       0.0551  119.951               4
# 113    0.0884   -10.744       0.3230   70.142               4
# 103    0.2090    -6.474       0.0279  124.970               4

# %%
sse = []
k_rng = range(1, 10)
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit_predict(dataset)
    sse.append(km.inertia_)

plt.plot(k_rng, sse)
plt.xlabel('K')
plt.ylabel('Sum of Squared Error', fontsize=16)
plt.title('Elbow Method', fontfamily='sans-serif', fontsize=16, fontweight="bold")
# Out:
# C:\Users\thalibarrifqi\anaconda3\envs\spotify\lib\site-packages\sklearn\cluster\_kmeans.py:1039: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Text(0.5, 1.0, 'Elbow Method')

# %%
# Modeling
model = KMeans(n_clusters=2)
y_pred = model.fit_predict(dataset)

# add cluster to new column
df['cluster'] = y_pred
# Out:
# C:\Users\THALIB~1\AppData\Local\Temp/ipykernel_7748/362203303.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster'] = y_pred

# %%
df['cluster'].value_counts()
# Out:
# 0    184
# 1     72
# Name: cluster, dtype: int64

# %%
df.head()
# Out:
#                          name                      album         artist  \
# 5                        2002   Speak Your Mind (Deluxe)     Anne-Marie
# 118  2U (feat. Justin Bieber)                          7   David Guetta
# 87                    7 Years  Lukas Graham (Blue Album)   Lukas Graham
# 113                   7 rings                    7 rings  Ariana Grande
# 103       A Sky Full of Stars              Ghost Stories       Coldplay
#
#     release_date  length  popularity  acousticness  danceability  energy  \
# 5     2018-04-27  186986          82       0.03720         0.697   0.683
# 118   2018-09-14  194893          61       0.23400         0.534   0.613
# 87    2015-06-16  237300          52       0.29000         0.742   0.479
# 113   2019-01-18  178640           2       0.57800         0.725   0.321
# 103   2014-05-19  267866          78       0.00617         0.545   0.675
#
#      instrumentalness  liveness  loudness  speechiness    tempo  \
# 5             0.00000    0.1370    -2.881       0.1170   96.133
# 118           0.00000    0.2270    -7.410       0.0591  144.878
# 87            0.00000    0.3910    -5.830       0.0551  119.951
# 113           0.00000    0.0884   -10.744       0.3230   70.142
# 103           0.00197    0.2090    -6.474       0.0279  124.970
#
#      time_signature  cluster
# 5                 4        0
# 118               4        0
# 87                4        1
# 113               4        0
# 103               4        1
